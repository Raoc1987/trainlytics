# %% [markdown]
# # Modelagem e Detecção de Platôs
# Este notebook aplica modelos simples para identificar platôs de progresso.

# %%
from workout_insights import model
# df já carregado e processado
result = model.detect_plateau(df)
