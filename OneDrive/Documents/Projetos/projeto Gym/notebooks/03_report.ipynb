# %% [markdown]
# # Relatório Final
# Este notebook gera visualizações e recomendações finais a partir dos dados de treino.

# %%
from workout_insights import recommender
# df já processado
recs = recommender.suggest_progression(df)
