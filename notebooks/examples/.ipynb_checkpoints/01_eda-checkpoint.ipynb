# %% [markdown]
# # Análise Exploratória de Dados (EDA)
# Este notebook explora os logs de treino e apresenta métricas iniciais.

# %%
import pandas as pd
from workout_insights import ingest, clean, features

df = ingest.load_workout_csv('../data/sample_workout_log.csv')
df = clean.clean_workout_data(df)
df = features.compute_metrics(df)
df.head()
